# %% [markdown]
# This notebook demonstrates a ssimple linear regression anayssis using Python to model salary based on years of experience. It also shows slope, the y-intercept, pearson's correlationn (r), and MSE (mean squared error).

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
from sklearn.metrics import mean_squared_error

dataset = pd.read_csv("regression_data-1.csv")
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# line: y=mx+b
# slope (m): change in salary with one year of experience
# y-intercept (b): predicted salary when experience is 0 years
# r (correlation): strength of relationship between salary and years of experience
# MSE: mean squared error between the actual and the predicted salary

# %%
x = dataset["YearsExperience"]
y = dataset["Salary"]

slope, intercept, r_value, p_value, std_err = linregress(x, y)
y_pred = slope * x + intercept
mse = mean_squared_error(y, y_pred)

print("Slope:", slope)
print("Intercept:", intercept)
print("Correlation coefficient (r):", r_value)
print("Mean Squared Error (MSE):", mse)
# Out:
# Slope: 8285.292099903525
# Intercept: 29203.522671240222
# Correlation coefficient (r): 0.8860877983098836
# Mean Squared Error (MSE): 17523844.082902785

# %% [markdown]
# #Interpretation of the results
# slope: for each additional year of experience, the salary increases by about [8285.29].
# y-intercept: the predicted starting salary (0 years of experience) is [29,203.52]
# correlation coefficient (r): 0.89, which indicates a positive linear relationship between sssalary and years of experience (i.e. both are increasing)
# MSE: average squared error in dollars; the root of this is about [4,200] (the model is off in it's prediction by about [4,200])

# %%
plt.scatter(x, y, color="red")
plt.plot(x, y_pred, "r-", label="Fitted Line")
plt.text(
    max(x) * 0.55,
    min(y) + (max(y) - min(y)) * 0.15,
    f"y = {slope:.2f}x + {intercept:.2f}\n"
    f"r = {r_value:.2f}\nMSE = {mse:.2f}",
    fontsize=12,
)
plt.title("Salary vs Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.legend()
plt.show()
